# %%
import pandas as pd
import copy
from datetime import date,datetime,timedelta
import numpy as np
import json
import os
import pickle
import csv
from calendar import monthrange
import urllib2
import urllib
from bs4 import BeautifulSoup

# %%
 url = 'http://appcenter.grupoice.com/CenceWeb/CencePosdespachoNacional.jsf'
 response = urllib2.urlopen(url)
 data = response.read()

# %%
print data
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <!DOCTYPE html >
# <html xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <title>Posdespacho Nacional</title>
# 		<meta http-equiv="X-UA-Compatible" content="IE=EmulateIE8" />
# <!-- Common -->
# <meta charset="UTF-8" />
# <meta name="GENERATOR" content="Rational Application Developer" />
# <meta http-equiv="Content-Style-Type" content="text/css" />
# <meta http-equiv="CACHE-CONTROL" content="NO-CACHE" />
# <meta http-equiv="EXPIRES" content="Mon, 22 Jul 2002 11:12:01 GMT" />
#
# <link class="component" href="/CenceWeb/faces/a4j/s/3_3_3.Finalorg/richfaces/renderkit/html/css/basic_both.xcss/DATB/eAF7sqpgb-jyGdIAFrMEaw__" rel="stylesheet" type="text/css" /><link class="component" href="/CenceWeb/faces/a4j/s/3_3_3.Finalorg/richfaces/renderkit/html/css/extended_both.xcss/DATB/eAF7sqpgb-jyGdIAFrMEaw__" media="rich-extended-skinning" rel="stylesheet" type="text/css" /><script src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg.ajax4jsf.javascript.AjaxScript" type="text/javascript"></script><script src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg.ajax4jsf.javascript.PrototypeScript" type="text/javascript"></script><script src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg/richfaces/renderkit/html/scripts/events.js" type="text/javascript"></script><script src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg/richfaces/renderkit/html/scripts/utils.js" type="text/javascript"></script><script src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg/richfaces/renderkit/html/scripts/json/json-dom.js" type="text/javascript"></script><script src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg/richfaces/renderkit/html/scripts/scriptaculous/effects.js" type="text/javascript"></script><script src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg/richfaces/renderkit/html/scripts/jquery/jquery.js" type="text/javascript"></script><script src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg/richfaces/renderkit/html/scripts/JQuerySpinBtn.js" type="text/javascript"></script><script src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg/richfaces/renderkit/html/scripts/calendar.js" type="text/javascript"></script><link class="component" href="/CenceWeb/faces/a4j/s/3_3_3.Finalorg/richfaces/renderkit/html/css/calendar.xcss/DATB/eAF7sqpgb-jyGdIAFrMEaw__" rel="stylesheet" type="text/css" /><link class="component" href="/CenceWeb/faces/a4j/s/3_3_3.Finalcss/table.xcss/DATB/eAF7sqpgb-jyGdIAFrMEaw__" rel="stylesheet" type="text/css" /><script type="text/javascript">window.RICH_FACES_EXTENDED_SKINNING_ON=true;</script><script src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg/richfaces/renderkit/html/scripts/skinning.js" type="text/javascript"></script><link href="resources/themeDefault/images/ice.ico" rel="icon" sizes="any" />
# <link type="image/x-icon" href="resources/themeDefault/images/ice.ico" rel="shortcut icon" />
#
#
# <link rel="stylesheet" href="resources/themeDefault/css/layout.css" type="text/css" />
# <link rel="stylesheet" href="resources/themeDefault/css/cence.css" type="text/css" />
# <link rel="stylesheet" href="resources/themeDefault/css/banner.css" type="text/css" />
# <link rel="stylesheet" href="resources/themeDefault/css/menu.css" type="text/css" />
# <link rel="stylesheet" href="resources/themeDefault/css/cenceTablas.css" type="text/css" />
#
# <!-- Common-->
# 			<meta http-equiv="X-UA-Compatible" content="IE=EmulateIE8" />
#
# 		<script type="text/javascript">
# 		//<![CDATA[
# 			function isDayEnabled(day) {
# 				var date = new Date(day.date);
# 				var pastTomorrow = new Date().setDate(new Date().getDate() + 1);
# 				var valid = (date < pastTomorrow);
# 				return valid;
# 			}
# 			function getDisabledStyle(day) {
# 				if (!isDayEnabled(day))
# 					return 'rich-calendar-boundary-dates disabledDay';
# 			}
# 			//]]>
# 		</script>
# 		<link rel="stylesheet" href="resources/cssScroll/scroll.css" type="text/css" />
#
#
# <!-- FusionCharts -->
# <script type="text/javascript" src="resources/FusionChart/js/FusionCharts.js"></script>
# <script type="text/javascript" src="resources/FusionChart/js/jquery.min.js"></script>
# <script type="text/javascript" src="resources/jQuery/jquery.jqplugin.1.0.2.min.js"></script>
# <script>
# 	jQuery.noConflict();
# </script>
# <!-- / END FusionCharts -->
# </head>
# 	<body><div id="globalContainer"><div id="content">
#
#
# <div id="banner">
# 					<table id="banner-table">
# 						<tr>
# 							<td><a href="http://www.grupoice.com"><img id="banner1" src="resources/themeDefault/images/banner/plantilla_r1_a1.jpg" width="125" alt="" /></a>
# 							</td>
# 							<td><img id="banner2" src="resources/themeDefault/images/banner/plantilla_r1_a2.jpg" width="519" alt="" />
# 							</td>
# 							<td><img id="banner3" src="resources/themeDefault/images/banner/plantilla_r1_a3.jpg" width="551" alt="" />
# 							</td>
# 						</tr>
# 					</table>
# 					</div>
# 					<div class="estiloSpacerDatos">7 de febrero de 2016 02:12 AM
# 					&nbsp;
# 				</div><div class="menuArea">
# 		<nav>
# 			<div>
# 				<ul class="menu"><li><a href="CenceMain.jsf"> Inicio</a></li>  <li><a href="#"> Operador del sistema</a>   <ul>    <li><a href="#"> Operaci&oacute;n tiempo real</a>     <ul>      <li><a href="CenceCurvaDemandaSEN.jsf?init=true"> Curva de        demanda</a></li>      <li><a href="CenceIntercambiosRegionalesSEN.jsf?init=true">        Intercambios regionales</a></li>      <li><a href="CenceReservasSEN.jsf?init=true"> Reserva        primaria y secundaria</a></li>     </ul></li>    <li><a href="#"> Informaci&oacute;n diaria</a>     <ul>      <li><a href="CencePredespachoTecnicoNacional.jsf?init=true">        Predespacho t&eacute;cnico nacional</a></li>      <li><a href="CencePosdespachoNacional.jsf?init=true">        Posdespacho nacional</a></li>      <li><a       href="CenceDescargaArchivo.jsf?init=true&categoria=3&codigoTipoArchivo=3001&fecha_inic=ante">        Operaci&oacute;n diaria</a></li>      <li><a href="CencePosdespachosDiarios.jsf?init=true">        Gr&aacute;fico de la operaci&oacute;n del SEN</a></li>      <li><a href="CenceIntercambios.jsf?init=true"> Intercambios        programados y ejecutados</a></li>      <li><a       href="CenceDescargaArchivos.jsf?init=true&amp;categoria=3&amp;codigoTipoArchivo=3010">      Bolet&iacute;n estado del SEN</a></li>     </ul></li>    <li><a href="#"> Eventos</a>     <ul>          <li><a       href="CenceDescargaArchivos.jsf?init=true&amp;categoria=5&amp;codigoTipoArchivo=5004">        Programa de indisponibilidades semanales</a></li>      <li><a       href="CenceDescargaArchivos.jsf?init=true&amp;categoria=3&amp;codigoTipoArchivo=3004">        Reporte de indisponibilidades del d&iacute;a anterior</a></li>          <li><a     href="CenceDescargaArchivos.jsf?init=true&amp;categoria=3&amp;codigoTipoArchivo=3011">      Informes de eventos en el sistema</a></li>     <li><a     href="CenceDescargaArchivos.jsf?init=true&amp;categoria=3&amp;codigoTipoArchivo=3012">      Disponibilidades de transmisi&oacute;n</a></li>     </ul></li>    <li><a     href="CenceDescargaArchivos.jsf?init=true&amp;categoria=3&amp;codigoTipoArchivo=3005">      Plan anual de mantenimiento</a></li>   </ul></li>  <li><a href="#"> Operador del mercado</a>   <ul>    <li><a href="#"> Informaci&oacute;n diaria</a>    <ul>     <li><a      href="CenceDescargaArchivos.jsf?init=true&amp;categoria=2&amp;codigoTipoArchivo=2017">       Posdespacho y desviaci&oacute;n diaria</a></li>     <li><a      href="CenceDescargaArchivos.jsf?init=true&amp;categoria=2&amp;codigoTipoArchivo=2018">       Conciliaci&oacute;n diaria</a></li>     <li><a      href="CenceDescargaArchivos.jsf?init=true&amp;categoria=2&amp;codigoTipoArchivo=2014">       Transacciones Mercado de Contratos Regional</a></li>     <li><a      href="CenceDescargaArchivos.jsf?init=true&amp;categoria=2&amp;codigoTipoArchivo=2015">       Transacciones Mercado de Oportunidad Regional</a></li>     <li><a      href="CenceDescargaArchivos.jsf?init=true&amp;categoria=2&amp;codigoTipoArchivo=2019">       Conciliaci&oacute;n diaria servicios de transmisi&oacute;n por agente</a></li>    </ul></li>      <li><a href="#"> Informaci&oacute;n mensual</a>    <ul>     <li><a      href="CenceDescargaArchivos.jsf?init=true&amp;categoria=2&amp;codigoTipoArchivo=2020">       Facturaci&oacute;n y liquidaci&oacute;n de transacciones MER-DTER </a></li>     <li><a      href="CenceDescargaArchivos.jsf?init=true&amp;categoria=2&amp;codigoTipoArchivo=2011">       Facturaci&oacute;n y liquidaci&oacute;n de transacciones MEN</a></li>     <li><a      href="CenceDescargaArchivos.jsf?init=true&amp;categoria=2&amp;codigoTipoArchivo=2021">       Informaci&oacute;n hist&oacute;rica proveniente del intercambio entre agentes del MER</a></li>     <li><a     href="CenceDescargaArchivos.jsf?init=true&amp;categoria=4&amp;codigoTipoArchivo=4067">      Ingresos agentes transmisores MER</a></li>     <li><a      href="CenceDescargaArchivos.jsf?init=true&amp;categoria=2&amp;codigoTipoArchivo=2022">       Cargos de op ...
# 				</ul>
# 			</div>
# 		</nav></div><div id="espacioSuperior"></div><div id="cuerpoContenido"><div id="contenidoPrincipal"><div id="tituloPagina" class="tit_04_naranja"><div id="textoTitulo">
# 		<div><span class="titulo">Sistema El&eacute;ctrico Nacional - Costa Rica</span>
# 		</div>
# 			<div><span class="titulo">Informaci&oacute;n Diaria</span>
# 		</div>
# 			<div><span class="titulo">Posdespacho Nacional, MWh</span>
# 		</div>
# 			<div><span id="tituloFecha" class="tituloFecha">s&aacute;bado 6 de febrero de 2016</span>
# 		</div></div></div><div class="contenido">
# <form id="formPosdespacho" name="formPosdespacho" method="post" action="/CenceWeb/CencePosdespachoNacional.jsf" enctype="application/x-www-form-urlencoded">
# <input type="hidden" name="formPosdespacho" value="formPosdespacho" />
#
#
# 				<div align="center"><img alt="" class="rich-spacer " height="30" id="formPosdespacho:j_id29" src="/CenceWeb/faces/a4j/g/3_3_3.Finalimages/spacer.gif" width="1" />
# 					<div style="text-align: left"><span class="Tit_04_gris">Seleccione una fecha a consultar</span><span id="formPosdespacho:pickFechaPopup"><input class="rich-calendar-input " id="formPosdespacho:pickFechaInputDate" name="formPosdespacho:pickFechaInputDate" style="vertical-align: middle; " type="text" value="05/02/2016" readonly="readonly" /><img alt="" class="rich-calendar-button " id="formPosdespacho:pickFechaPopupButton" style="vertical-align: middle" src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg.richfaces.renderkit.html.iconimages.CalendarIcon/DATB/eAH7cW0fw6znAA8XBA4_" /><input autocomplete="off" id="formPosdespacho:pickFechaInputCurrentDate" name="formPosdespacho:pickFechaInputCurrentDate" style="display:none" type="hidden" value="02/2016" /><style type="text/css">.formPosdespacho_pickFechaDayCell{width:24px;height:22px;}</style></span><div id="formPosdespacho:pickFechaIFrame" style="display: none;"></div><div id="formPosdespacho:pickFecha" style="display: none;"></div><div id="formPosdespacho:pickFechaScript" style="display: none;"><script type="text/javascript">Richfaces.Calendar.addLocale('es_CR', {'weekDayLabels':['domingo','lunes','martes','miércoles','jueves','viernes','sábado'] ,'weekDayLabelsShort':['dom','lun','mar','mié','jue','vie','sáb'] ,'monthLabels':['enero','febrero','marzo','abril','mayo','junio','julio','agosto','septiembre','octubre','noviembre','diciembre'] ,'monthLabelsShort':['ene','feb','mar','abr','may','jun','jul','ago','sep','oct','nov','dic'] ,'minDaysInFirstWeek':1,'firstWeekDay':1} );
# new Calendar('formPosdespacho:pickFecha',
# 			"es_CR",{'style':'z\x2Dindex: 500; width:200px','datePattern':'dd/MM/yyyy','currentDate':new Date(2016,1,5),'selectedDate':new Date(2016,1,5,20,12,0),'dayCellClass':'formPosdespacho_pickFechaDayCell'} ,{} ).load();</script></div><input type="image" src="resources/themeDefault/images/botones/search2.png" name="formPosdespacho:j_id32" alt="Consultar" title="Consultar" class="botonImagenPequenno" /><span id="_viewRoot:status"><span id="_viewRoot:status.start" style="display: none">Consultando...</span><span id="_viewRoot:status.stop"></span></span>
# 						</div><img alt="" class="rich-spacer " height="10" id="formPosdespacho:j_id36" src="/CenceWeb/faces/a4j/g/3_3_3.Finalimages/spacer.gif" width="1" />
# 								<div class="scrollable" id="scroll1" style="max-height: 600px;"><table class="rich-table tablaDatos" id="formPosdespacho:tableEx1" border="0" cellpadding="0" cellspacing="0" width="1060px"><colgroup span="26"></colgroup><thead class="rich-table-thead"><tr class="rich-table-subheader "><th class="rich-table-subheadercell  " scope="col" id="formPosdespacho:tableEx1:plantaheader" onclick="A4J.AJAX.Submit('formPosdespacho',event,{'similarityGroupingId':'formPosdespacho:tableEx1','parameters':{'fsp':'formPosdespacho:tableEx1:planta','formPosdespacho:tableEx1':'fsp'} } )" style="cursor: pointer;"><div id="formPosdespacho:tableEx1:plantaheader:sortDiv"><span class="rich-table-sortable-header"><span id="formPosdespacho:tableEx1:textPlantaEncabezado">Planta</span><img src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg.richfaces.renderkit.html.iconimages.DataTableIconSortNone/DATB/eAFjYGD4!!8!AAYAAv4_" alt="" width="15" height="15" class="rich-sort-icon" /></span></div></th><th class="rich-table-subheadercell  " scope="col" id="formPosdespacho:tableEx1:j_id38header" onclick="A4J.AJAX.Submit('formPosdespacho',event,{'similarityGroupingId':'formPosdespacho:tableEx1','parameters':{'fsp':'formPosdespacho:tableEx1:j_id38','formPosdespacho:tableEx1':'fsp'} } )" style="cursor: pointer;"><div id="formPosdespacho:tableEx1:j_id38header:sortDiv"><span class="rich-table-sortable-header"><span id="formPosdespacho:tableEx1:texthora0Encabezado">00:00</span><img src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg.richfaces.renderkit.html.iconimages.DataTableIconSortNone/DATB/eAFjYGD4!!8!AAYAAv4_" alt="" width="15" height="15" class="rich-sort-icon" /></span></div></th><th class="rich-table-subheadercell  " scope="col" id="formPosdespacho:tableEx1:j_id39header" onclick="A4J.AJAX.Submit('formPosdespacho',event,{'similarityGroupingId':'formPosdespacho:tableEx1','parameters':{'fsp':'formPosdespacho:tableEx1:j_id39','formPosdespacho:tableEx1':'fsp'} } )" style="cursor: pointer;"><div id="formPosdespacho:tableEx1:j_id39header:sortDiv"><span class="rich-table-sortable-header"><span id="formPosdespacho:tableEx1:texthora1Encabezado">01:00</span><img src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg.richfaces.renderkit.html.iconimages.DataTableIconSortNone/DATB/eAFjYGD4!!8!AAYAAv4_" alt="" width="15" height="15" class="rich-sort-icon" /></span></div></th><th class="rich-table-subheadercell  " scope="col" id="formPosdespacho:tableEx1:j_id40header" onclick="A4J.AJAX.Submit('formPosdespacho',event,{'similarityGroupingId':'formPosdespacho:tableEx1','parameters':{'fsp':'formPosdespacho:tableEx1:j_id40','formPosdespacho:tableEx1':'fsp'} } )" style="cursor: pointer;"><div id="formPosdespacho:tableEx1:j_id40header:sortDiv"><span class="rich-table-sortable-header"><span id="formPosdespacho:tableEx1:texthora2Encabezado">02:00</span><img src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg.richfaces.renderkit.html.iconimages.DataTableIconSortNone/DATB/eAFjYGD4!!8!AAYAAv4_" alt="" width="15" height="15" class="rich-sort-icon" /></span></div></th><th class="rich-table-subheadercell  " scope="col" id="formPosdespacho:tableEx1:j_id41header" onclick="A4J.AJAX.Submit('formPosdespacho',event,{'similarityGroupingId':'formPosdespacho:tableEx1','parameters':{'fsp':'formPosdespacho:tableEx1:j_id41','formPosdespacho:tableEx1':'fsp'} } )" style="cursor: pointer;"><div id="formPosdespacho:tableEx1:j_id41header:sortDiv"><span class="rich-table-sortable-header"><span id="formPosdespacho:tableEx1:texthora3Encabezado">03:00</span><img src="/CenceWeb/faces/a4j/g/3_3_3.Finalorg.richfaces.renderkit.html.iconimages.DataTableIconSortNone/DATB/eAFjYGD4!!8!AAYAAv4_" alt="" width="15" height="15" class="rich-sort-icon" /></span></div></th><th class="rich-table-subheadercell  " scope="col" id="formPosdespacho:tableEx1:j_id42header" onclick="A4J.AJAX.Submit('formPosdespacho',event,{'similarityGroupingId':'formPosdespacho:tableEx1','parameters':{'fsp':'formPosdespacho:tableEx1:j_id42','formPosdespacho:tableEx1':'fsp'} } )" style=" ...
# 									</div><div class="leyenda">Fuente: ICE Costa Rica</div><input type="image" src="resources/themeDefault/images/botones/xls.png" name="formPosdespacho:j_id65" title="Generar documento de Excel" class="botonImagen" /><input type="image" src="resources/themeDefault/images/botones/pdf.png" name="formPosdespacho:j_id66" title="Generar documento de PDF" class="botonImagen" />
# 				</div><input type="hidden" name="javax.faces.ViewState" id="javax.faces.ViewState" value="..." />
# </form></div></div><div id="certificaciones"><div class="certificado"><div class="tumbnail certificado1"><a href="resources/themeDefault/images/certificado.png"></a></div><div class="large certificado1"><a href="resources/themeDefault/images/certificado.png"></a></div></div></div><div class="footer">
# 	<footer>
# 						<div class="footer">Centro Nacional de Control de Energ&iacute;a. Instituto Costarricense de Electricidad - CENCE.
# 							<br />El CENCE no se hace responsable de ning&uacute;n error u omisi&oacute;n, p&eacute;rdidas o da&ntilde;os que resulten de la utilizaci&oacute;n de la informaci&oacute;n o material contenidos en este sitio.
# 							<br />Declaraci&oacute;n de Privacidad &copy; 2013 ICE Todos los Derechos Reservados.
# 							<br />&Uacute;ltima Actualizaci&oacute;n del Sistema, Marzo 2014 - Versi&oacute;n 2.6.5
# 						</div>
# 					</footer></div></div></div><input type="hidden" name="j_id83" value="" /></div>
# 	</body>
# </html>
